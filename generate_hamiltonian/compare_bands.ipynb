# %%
import numpy as np
import matplotlib.pyplot as plt
from utils import split_data_by_bands

# %%
wt_path = "BLG/5by2_3rd_neighbor/potential_0"
wt_file = f"{wt_path}/bulkek.dat"
my_path = "BLG/output/5x2/3/sine/potential_0"
my_file = f"{my_path}/bulkek.dat"

# %%
bands_wt = split_data_by_bands(wt_file)[7]
bands_my = split_data_by_bands(my_file)[7]

# %%
print(bands_my.shape)
# Out:
# (63, 5)

# %%
plt.plot(bands_wt[:,3],bands_wt[:,4],'o',c="red",label="wanniertools")
plt.plot(bands_my[:,3],bands_my[:,4],'o',c="black",label="mine")
