# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def split_data_by_bands(filename):
    bands = []
    current_band_data = []

    with open(filename, 'r') as file:
        next(file)

        for line in file:
            if line.strip():  # Check if the line is not empty
                data = line.split()
                current_band_data.append([float(val) for val in data])
            else:
                bands.append(current_band_data)
                current_band_data = []

        if current_band_data:
            bands.append(current_band_data)

    return np.array(bands)

# %%
potentials = [".02",]#".045",".095",".90"]# ".50",".75","1.00","1.25"]
xtics =  [    0.00000,    0.85137,    1.27707,    1.29243,    2.56950,    2.58486,    3.86202]
xlabels = ["G","P","X","W","Y","G","W"]
for potential in potentials:

    plt.figure(figsize=(20,8))
    bands = split_data_by_bands(f"sparse/potential_{potential}/bulkek.dat")
    klen = bands[19][:,3]
    for band_index in range(10,30):
        band = bands[band_index][:,4]
        plt.plot(klen,band,'.')#,label=f"V = {potential} eV")
    plt.ylim(-0.05,0.09)
    # plt.xlim(0.2,0.6)
    plt.ylabel("E (eV)")
    plt.xlabel("k")
    plt.axhline(0, color='gray', linewidth=1.5)
    # plt.xticks(labels=xlabels,ticks=xtics)
    plt.legend()
    plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
potentials = ["0.01",]#".045",".095",".90"]# ".50",".75","1.00","1.25"]
xtics =  [    0.00000,    0.85137,    1.27707,    1.29243,    2.56950,    2.58486,    3.86202]
xlabels = ["G","P","X","W","Y","G","W"]
for potential in potentials:

    plt.figure(figsize=(20,8))
    bands = split_data_by_bands(f"sparse/generated/potential_{potential}/bulkek.dat")
    klen = bands[19][:,3]
    for band_index in range(10,30):
        band = bands[band_index][:,4]
        plt.plot(klen,band,'.')#,label=f"V = {potential} eV")
    plt.ylim(-0.01,0.01)
    # plt.xlim(0.2,0.6)
    plt.ylabel("E (eV)")
    plt.xlabel("k")
    plt.axhline(0, color='gray', linewidth=1.5)
    # plt.xticks(labels=xlabels,ticks=xtics)
    plt.legend()
    plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
