# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Necessary when connecting to a jupyterhub kernel running on daint via VScode. NOT required otherwise
import os
new_path = '/scratch/snx3000/ajayaraj/tests/periodic-potential/daint/BLG/tb-hamiltonian'
os.chdir(new_path)

# %%
bands = np.load("len_500.0x288.675/nn_1/null/bands.npy")
distances = np.load("len_500.0x288.675/nn_1/null/distances.npy")

plt.plot(distances,bands,'.')
plt.ylim(-0.03,0.03)
plt.show()

# %%
bands = np.load("len_500.0x72.169/nn_1/null/bands.npy")
distances = np.load("len_500.0x72.169/nn_1/null/distances.npy")

plt.plot(distances,bands,'.')
plt.ylim(-0.1,0.1)
plt.show()

# %%
bands = np.load("len_503.0x290.407/nn_1/rectangular/amplitude_0.06999999999999999/nx_ny_2_2/alpha_(1.0, 0.3)/eigenvalues.npy")
distances = np.load("len_503.0x290.407/nn_1/rectangular/amplitude_0.06999999999999999/nx_ny_2_2/alpha_(1.0, 0.3)/distances.npy")
print(distances)
for band in bands.T:
    plt.scatter(distances,band,c = "k",s=1)
# plt.ylim(-0.03,0.03)
plt.show()
# Out:
# []
