# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Necessary when connecting to a jupyterhub kernel running on daint via VScode. NOT required otherwise
import os
new_path = '/scratch/snx3000/ajayaraj/tests/periodic-potential/daint/BLG/tb-hamiltonian'
os.chdir(new_path)

# %%
bands = np.load("len_304.0x2.7/nn_1/kronig-penney-break-odd-sym/amplitude_0.05/width_0.5/alpha_0.9000000000000001/bands.npy")
distances = np.load("len_304.0x2.7/nn_1/kronig-penney-break-odd-sym/amplitude_0.05/width_0.5/alpha_0.9000000000000001/distances.npy")

plt.plot(distances,bands,'.')
plt.ylim(-1,1)
plt.show()
