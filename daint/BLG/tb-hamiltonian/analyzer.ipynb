# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
bands = np.load("rep_25x1/nn_1/null/bands.npy")
distances = np.load("rep_25x1/nn_1/null/distances.npy")

plt.plot(distances,bands)
plt.ylim(-1,1)
plt.show()
